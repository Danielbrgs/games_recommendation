# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import joblib

# %%
# Get data
def get_steam_data(file_path:str) -> pd.DataFrame:
  column_names = ['user_id', 'item_id', 'behaviour', 'hours']
  df = pd.read_csv(file_path, header=None, names=column_names, usecols=range(4))
  return df

# %%
df = get_steam_data('..\data\steam-200k.csv')
df.head()
# Out:
#      user_id                     item_id behaviour  hours
# 0  151603712  The Elder Scrolls V Skyrim  purchase    1.0
# 1  151603712  The Elder Scrolls V Skyrim      play  273.0
# 2  151603712                   Fallout 4  purchase    1.0
# 3  151603712                   Fallout 4      play   87.0
# 4  151603712                       Spore  purchase    1.0

# %%
df_play = df.query('behaviour == "play"')
df_play.head() # vamos filtrar apenas as horas jogadas
# Out:
#      user_id                     item_id behaviour  hours
# 1  151603712  The Elder Scrolls V Skyrim      play  273.0
# 3  151603712                   Fallout 4      play   87.0
# 5  151603712                       Spore      play   14.9
# 7  151603712           Fallout New Vegas      play   12.1
# 9  151603712               Left 4 Dead 2      play    8.9

# %%
df_user_total_hours = df_play.groupby(['user_id'])['hours'].sum().reset_index()
df_user_total_hours.head() # agore tenho as horas totais jogadas por cada jogador
# Out:
#    user_id   hours
# 0     5250   225.5
# 1    76767  1227.0
# 2    86540   255.0
# 3   144736     0.1
# 4   181212     2.2

# %%
df_games_played = df_play.groupby(['user_id'])['item_id'].count().reset_index() 
df_games_played.head()# este df, tem a quantidade de jogos jogados por cada usuário
# Out:
#    user_id  item_id
# 0     5250        6
# 1    76767       20
# 2    86540       15
# 3   144736        1
# 4   181212        2

# %%
df_user_mean_hours = df_games_played.merge(df_user_total_hours, on='user_id')
df_user_mean_hours['mean_hours'] = df_user_mean_hours['hours']/df_user_mean_hours['item_id']
df_user_mean_hours = df_user_mean_hours.drop(columns=['item_id', 'hours'])
df_user_mean_hours.head() # este df contém as horas médias que cada usuário gasta com os jogos jogados
# Out:
#    user_id  mean_hours
# 0     5250   37.583333
# 1    76767   61.350000
# 2    86540   17.000000
# 3   144736    0.100000
# 4   181212    1.100000

# %%
df_play = df_play.merge(df_user_mean_hours, on='user_id',how='left')
df_play = df_play.drop(columns=['behaviour'])
df_play.head()
# Out:
#      user_id                     item_id  hours  mean_hours
# 0  151603712  The Elder Scrolls V Skyrim  273.0   16.919231
# 1  151603712                   Fallout 4   87.0   16.919231
# 2  151603712                       Spore   14.9   16.919231
# 3  151603712           Fallout New Vegas   12.1   16.919231
# 4  151603712               Left 4 Dead 2    8.9   16.919231

# %%
df_play['rating']= df_play['hours']/df_play['mean_hours']
df_play.head()
# foi criada uma forma de avaliação implícita em que as horas jogadas de cada jogo é dividida pelas horas médias em que o jogador gasta em cada jogo que ele jogou
# esta métrica pesa muito quando o jogo prende o jogador por muitas horas
# caso o jogador tenha mais jogos, a métrica vai disparar para jogares que jogaram muitos jogos e concentraram horas em algum jogo específico.
# este rating não avalia q qualidade do jogo em si, e sim o quão viciante ele é
# Out:
#      user_id                     item_id  hours  mean_hours     rating
# 0  151603712  The Elder Scrolls V Skyrim  273.0   16.919231  16.135485
# 1  151603712                   Fallout 4   87.0   16.919231   5.142078
# 2  151603712                       Spore   14.9   16.919231   0.880655
# 3  151603712           Fallout New Vegas   12.1   16.919231   0.715163
# 4  151603712               Left 4 Dead 2    8.9   16.919231   0.526029

# %%
df_games = df_play.groupby(['item_id'])['hours'].sum().reset_index() 
df_games.head() # este será o dataframe dos games, de inicio estou somando horas jogadas em cada um deles
# Out:
#                                              item_id  hours
# 0                                        007 Legends    0.7
# 1                                          0RBITALIS    1.2
# 2  1... 2... 3... KICK IT! (Drop That Beat Like a...   20.0
# 3                                    10 Second Ninja    5.9
# 4                                         10,000,000    3.6

# %%
df_games = df_games.merge(df_play.groupby(['item_id'])['rating'].mean().reset_index(), on='item_id')
df_games.head() # agora tenho a média de rating para cada jogo
# Out:
#                                              item_id  hours    rating
# 0                                        007 Legends    0.7  0.014867
# 1                                          0RBITALIS    1.2  0.027865
# 2  1... 2... 3... KICK IT! (Drop That Beat Like a...   20.0  0.369785
# 3                                    10 Second Ninja    5.9  0.227901
# 4                                         10,000,000    3.6  0.262751

# %%
df_games = df_games.merge(df.query('behaviour == "purchase"').groupby(['item_id'])['behaviour'].count().reset_index(),
                          on='item_id')
df_games.head() # compras feitas em cada jogo
# Out:
#                                              item_id  hours    rating  \
# 0                                        007 Legends    0.7  0.014867
# 1                                          0RBITALIS    1.2  0.027865
# 2  1... 2... 3... KICK IT! (Drop That Beat Like a...   20.0  0.369785
# 3                                    10 Second Ninja    5.9  0.227901
# 4                                         10,000,000    3.6  0.262751
#
#    behaviour
# 0          1
# 1          3
# 2          7
# 3          6
# 4          1

# %%
df_games = df_games.rename(columns={
    'hours': 'total_hours',
    'rating': 'mean_rating',
    'behaviour': 'total_purchases'
})
df_games.head()
# Out:
#                                              item_id  total_hours  \
# 0                                        007 Legends          0.7
# 1                                          0RBITALIS          1.2
# 2  1... 2... 3... KICK IT! (Drop That Beat Like a...         20.0
# 3                                    10 Second Ninja          5.9
# 4                                         10,000,000          3.6
#
#    mean_rating  total_purchases
# 0     0.014867                1
# 1     0.027865                3
# 2     0.369785                7
# 3     0.227901                6
# 4     0.262751                1

# %%
# top10 jogos mais jogados
df_games.sort_values(by='total_hours',ascending=False).head(10)
# Out:
#                                           item_id  total_hours  mean_rating  \
# 922                                        Dota 2     981684.6     1.756914
# 673               Counter-Strike Global Offensive     322771.6     3.918016
# 2994                              Team Fortress 2     173673.3     1.783639
# 670                                Counter-Strike     134261.1     1.596892
# 2691                   Sid Meier's Civilization V      99821.3     2.589208
# 675                         Counter-Strike Source      96075.5     1.883556
# 3067                   The Elder Scrolls V Skyrim      70889.3     2.958108
# 1313                                  Garry's Mod      49725.3     2.281203
# 490   Call of Duty Modern Warfare 2 - Multiplayer      42009.9     2.383160
# 1733                                Left 4 Dead 2      33596.7     1.147005
#
#       total_purchases
# 922              4841
# 673              1412
# 2994             2323
# 670               856
# 2691              596
# 675               978
# 3067              717
# 1313              731
# 490               343
# 1733              951

# %%
# top10 jogos mais comprados
df_games.sort_values(by='total_purchases',ascending=False).head(10)
# Out:
#                               item_id  total_hours  mean_rating  \
# 922                            Dota 2     981684.6     1.756914
# 2994                  Team Fortress 2     173673.3     1.783639
# 3350                         Unturned      16096.4     0.926801
# 673   Counter-Strike Global Offensive     322771.6     3.918016
# 1448           Half-Life 2 Lost Coast        184.4     0.122918
# 675             Counter-Strike Source      96075.5     1.883556
# 1733                    Left 4 Dead 2      33596.7     1.147005
# 670                    Counter-Strike     134261.1     1.596892
# 3426                         Warframe      27074.6     1.700296
# 1445           Half-Life 2 Deathmatch       3712.9     0.359893
#
#       total_purchases
# 922              4841
# 2994             2323
# 3350             1563
# 673              1412
# 1448              981
# 675               978
# 1733              951
# 670               856
# 3426              847
# 1445              823

# %%
# top10 jogos mais bem avaliados
df_games.sort_values(by='mean_rating',ascending=False).head(10)
# esta avaliação não fez tanto sentido, pois pode-se observar que os jogos deste top tem poucas compras
# Out:
#                                        item_id  total_hours  mean_rating  \
# 1119                           FIFA Manager 09        411.0    18.564076
# 2146               Out of the Park Baseball 16        660.8    12.209546
# 354                                  Black Ink        239.3    10.681597
# 1973  Movie Studio 13 Platinum - Steam Powered        166.0     7.145301
# 1563                            Imperial Glory        170.0     6.830738
# 368            BlazBlue Continuum Shift Extend        233.8     5.410861
# 2909                          Sunrider Academy         43.0     5.402448
# 2145               Out of the Park Baseball 15        549.2     5.043428
# 3505             Worldwide Soccer Manager 2009        295.0     4.986543
# 1120                           FIFA Manager 11        229.0     4.863753
#
#       total_purchases
# 1119                1
# 2146                2
# 354                 3
# 1973                1
# 1563                4
# 368                 4
# 2909                1
# 2145                6
# 3505                1
# 1120                1

# %%
# top10 jogos mais bem avaliados
df_games[df_games['total_purchases'] > 800].sort_values(by='mean_rating',ascending=False).head(10)
# considerando jogos com mais de 800 compras, se tem um top que faz mais sentido
# Out:
#                               item_id  total_hours  mean_rating  \
# 673   Counter-Strike Global Offensive     322771.6     3.918016
# 675             Counter-Strike Source      96075.5     1.883556
# 2994                  Team Fortress 2     173673.3     1.783639
# 922                            Dota 2     981684.6     1.756914
# 3426                         Warframe      27074.6     1.700296
# 670                    Counter-Strike     134261.1     1.596892
# 1733                    Left 4 Dead 2      33596.7     1.147005
# 3350                         Unturned      16096.4     0.926801
# 1445           Half-Life 2 Deathmatch       3712.9     0.359893
# 1448           Half-Life 2 Lost Coast        184.4     0.122918
#
#       total_purchases
# 673              1412
# 675               978
# 2994             2323
# 922              4841
# 3426              847
# 670               856
# 1733              951
# 3350             1563
# 1445              823
# 1448              981

# %% [markdown]
# Os tops indicados seriam tops de todos os tempos, a maioria dos jogos que aprecem neles são gratuitos para jogar, enquanto outros são clássicos baratos.

# %%
df_play.head()
# Out:
#      user_id                     item_id  hours  mean_hours     rating
# 0  151603712  The Elder Scrolls V Skyrim  273.0   16.919231  16.135485
# 1  151603712                   Fallout 4   87.0   16.919231   5.142078
# 2  151603712                       Spore   14.9   16.919231   0.880655
# 3  151603712           Fallout New Vegas   12.1   16.919231   0.715163
# 4  151603712               Left 4 Dead 2    8.9   16.919231   0.526029

# %% [markdown]
# Vamos criar uma tabela de avaliação:
# * (Rating Matrix)
# Crie uma tabela onde as linhas são os item_id (jogos) e as colunas são os user_id (usuários), e os valores são os ratings implícitos.

# %%
# Cria a tabela pivot
df_play_drop = df_play.drop(columns=['hours','mean_hours'])

# %%
for i in df_play_drop['user_id'].unique(): # esta função procura duplicatas de jogos para cada usuário
    uid = "user_id == " + str(i)
    ps = df_play_drop.query(uid).duplicated('item_id')
    has_true_values = ps.any()
    if has_true_values == True:
        print(i)
# Out:
# 118664413
# 50769696
# 71411882
# 33865373
# 71510748
# 28472068
# 59925638
# 148362155
# 176261926

# %%
lista_duplicatas = [118664413,
50769696,
71411882,
33865373,
71510748,
28472068,
59925638,
148362155,
176261926
]

# %%
for i in lista_duplicatas:
    user_data = df_play_drop[df_play_drop['user_id'] == i]
    user_data_no_duplicates = user_data.drop_duplicates(subset='item_id', keep='first')
    df_play_drop.loc[user_data.index, :] = user_data_no_duplicates

# %%
df_play_drop = df_play_drop.dropna()

# %%
for i in df_play_drop['user_id'].unique(): # esta função procura duplicatas de jogos para cada usuário
    uid = "user_id == " + str(i)
    ps = df_play_drop.query(uid).duplicated('item_id')
    has_true_values = ps.any()
    if has_true_values == True:
        print(i)

        # pronto agora não tem mais duplicata

# %%
ratings_matrix = df_play_drop.pivot(index='item_id', columns='user_id', values='rating').fillna(0)
ratings_matrix.head()
# Out:
# user_id                                             5250.0       76767.0      \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             86540.0      144736.0     \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             181212.0     229911.0     \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             298950.0     381543.0     \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             547685.0     554278.0     \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             ...  309228590.0  \
# item_id                                             ...
# 007 Legends                                         ...          0.0
# 0RBITALIS                                           ...          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...  ...          0.0
# 10 Second Ninja                                     ...          0.0
# 10,000,000                                          ...          0.0
#
# user_id                                             309255941.0  309262440.0  \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             309265377.0  309404240.0  \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             309434439.0  309554670.0  \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             309626088.0  309824202.0  \
# item_id
# 007 Legends                                                 0.0          0.0
# 0RBITALIS                                                   0.0          0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0          0.0
# 10 Second Ninja                                             0.0          0.0
# 10,000,000                                                  0.0          0.0
#
# user_id                                             309903146.0
# item_id
# 007 Legends                                                 0.0
# 0RBITALIS                                                   0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0
# 10 Second Ninja                                             0.0
# 10,000,000                                                  0.0
#
# [5 rows x 11350 columns]

# %%
# Calcula a similaridade entre itens
item_similarity = cosine_similarity(ratings_matrix)
item_similarity_df = pd.DataFrame(item_similarity, index=ratings_matrix.index, columns=ratings_matrix.index)
item_similarity_df.head()
# Out:
# item_id                                             007 Legends  0RBITALIS  \
# item_id
# 007 Legends                                                 1.0   0.000000
# 0RBITALIS                                                   0.0   1.000000
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          0.0   0.000000
# 10 Second Ninja                                             0.0   0.082879
# 10,000,000                                                  0.0   0.000000
#
# item_id                                             1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby)  \
# item_id
# 007 Legends                                                                                       0.0
# 0RBITALIS                                                                                         0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                                                1.0
# 10 Second Ninja                                                                                   0.0
# 10,000,000                                                                                        0.0
#
# item_id                                             10 Second Ninja  \
# item_id
# 007 Legends                                                0.000000
# 0RBITALIS                                                  0.082879
# 1... 2... 3... KICK IT! (Drop That Beat Like an...         0.000000
# 10 Second Ninja                                            1.000000
# 10,000,000                                                 0.000000
#
# item_id                                             10,000,000  \
# item_id
# 007 Legends                                                0.0
# 0RBITALIS                                                  0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...         0.0
# 10 Second Ninja                                            0.0
# 10,000,000                                                 1.0
#
# item_id                                             100% Orange Juice  \
# item_id
# 007 Legends                                                       0.0
# 0RBITALIS                                                         0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                0.0
# 10 Second Ninja                                                   0.0
# 10,000,000                                                        0.0
#
# item_id                                             1000 Amps  \
# item_id
# 007 Legends                                               0.0
# 0RBITALIS                                                 0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...        0.0
# 10 Second Ninja                                           0.0
# 10,000,000                                                0.0
#
# item_id                                             12 Labours of Hercules  \
# item_id
# 007 Legends                                                            0.0
# 0RBITALIS                                                              0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                     0.0
# 10 Second Ninja                                                        0.0
# 10,000,000                                                             0.0
#
# item_id                                             12 Labours of Hercules II The Cretan Bull  \
# item_id
# 007 Legends                                                                               0.0
# 0RBITALIS                                                                                 0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                                        0.0
# 10 Second Ninja                                                                           0.0
# 10,000,000                                                                                0.0
#
# item_id                                             12 Labours of Hercules III Girl Power  \
# item_id
# 007 Legends                                                                           0.0
# 0RBITALIS                                                                             0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                                    0.0
# 10 Second Ninja                                                                       0.0
# 10,000,000                                                                            0.0
#
# item_id                                             ...  rFactor  rFactor 2  \
# item_id                                             ...
# 007 Legends                                         ...      0.0        0.0
# 0RBITALIS                                           ...      0.0        0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...  ...      0.0        0.0
# 10 Second Ninja                                     ...      0.0        0.0
# 10,000,000                                          ...      0.0        0.0
#
# item_id                                             realMyst  \
# item_id
# 007 Legends                                              0.0
# 0RBITALIS                                                0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...       0.0
# 10 Second Ninja                                          0.0
# 10,000,000                                               0.0
#
# item_id                                             realMyst Masterpiece Edition  \
# item_id
# 007 Legends                                                                  0.0
# 0RBITALIS                                                                    0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                           0.0
# 10 Second Ninja                                                              0.0
# 10,000,000                                                                   0.0
#
# item_id                                             resident evil 4 / biohazard 4  \
# item_id
# 007 Legends                                                                   0.0
# 0RBITALIS                                                                     0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                            0.0
# 10 Second Ninja                                                               0.0
# 10,000,000                                                                    0.0
#
# item_id                                             rymdkapsel  sZone-Online  \
# item_id
# 007 Legends                                                0.0      0.000000
# 0RBITALIS                                                  0.0      0.000000
# 1... 2... 3... KICK IT! (Drop That Beat Like an...         0.0      0.000146
# 10 Second Ninja                                            0.0      0.000000
# 10,000,000                                                 0.0      0.000000
#
# item_id                                             the static speaks my name  \
# item_id
# 007 Legends                                                               0.0
# 0RBITALIS                                                                 0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                        0.0
# 10 Second Ninja                                                           0.0
# 10,000,000                                                                0.0
#
# item_id                                             theHunter  \
# item_id
# 007 Legends                                          0.000000
# 0RBITALIS                                            0.005016
# 1... 2... 3... KICK IT! (Drop That Beat Like an...   0.000000
# 10 Second Ninja                                      0.000000
# 10,000,000                                           0.000000
#
# item_id                                             theHunter Primal
# item_id
# 007 Legends                                                      0.0
# 0RBITALIS                                                        0.0
# 1... 2... 3... KICK IT! (Drop That Beat Like an...               0.0
# 10 Second Ninja                                                  0.0
# 10,000,000                                                       0.0
#
# [5 rows x 3600 columns]

# %%
def recommend_items(item_id, item_similarity_df, num_recommendations=5):
    similar_items = item_similarity_df[item_id].sort_values(ascending=False) # ele pega a coluna do jogo e ordena ela
    similar_items = similar_items.drop(item_id)  # Remove o item atual
    return similar_items.head(num_recommendations) # com isso retorna os primeiros itens que são os mais semelhantes

# %%
recommend_items('Counter-Strike', item_similarity_df,10)
# Out:
# item_id
# Containment The Zombie Puzzler           0.455379
# Weird Worlds Return to Infinite Space    0.455379
# Space Warp                               0.455379
# Actual Sunlight                          0.455379
# Overture                                 0.455185
# Reprisal Universe                        0.455101
# Gigantic Army                            0.419344
# ProtoGalaxy                              0.417254
# Orborun                                  0.413713
# Counter-Strike Nexon Zombies             0.375760
# Name: Counter-Strike, dtype: float64

# %%
recommend_items('Fallout 4', item_similarity_df,10)
# Out:
# item_id
# Mega Man Legacy Collection          0.492852
# Myst V                              0.435477
# The Witcher 3 Wild Hunt             0.420982
# Satellite Reign                     0.328512
# Middle-earth Shadow of Mordor       0.318584
# Fallout New Vegas                   0.313947
# Overlord II                         0.312697
# Sins of a Solar Empire Rebellion    0.302871
# Gods Will Be Watching               0.302772
# Zeno Clash 2                        0.301537
# Name: Fallout 4, dtype: float64

# %% [markdown]
# ###### A matriz de similiaridade é feita a partir da matriz de avaliações.
# ###### As recomendações são baseadas nos padrões de jogos de usuários. Jogos frequentemente jogados pelos mesmos usuários são considerados semelhantes.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class RecommenderSystem:
#       2     def __init__(self, file_path:str):
#       3         self.df = self.get_steam_data(file_path)
#
# Cell In[1], line 7, in RecommenderSystem()
#       4     self.ratings_matrix = self.get_ratings_df(self.df)
#       5     self.item_similarity_df = self.get_similarity(self.ratings_matrix)
# ----> 7 def get_steam_data(self, file_path:str) -> pd.DataFrame:
#       8     column_names = ['user_id', 'item_id', 'behaviour', 'hours']
#       9     df = pd.read_csv(file_path, header=None, names=column_names, usecols=range(4))
#
# NameError: name 'pd' is not defined

# %%
# Caminho do arquivo de dados
file_path = 'steam_data.csv'

# Crie uma instância da classe
recommender = RecommenderSystem(file_path)

# Salve a instância da classe
joblib.dump(recommender, 'recommender_system.pkl')
